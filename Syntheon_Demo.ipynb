# %% [markdown]
# # Syntheon - Parameter Inference of Music Synthesizers using Deep Learning
#
# In this notebook, we will use [Syntheon](https://github.com/gudgud96/syntheon) for a simple demo on how parameter inference works.
#
# The synthesizer used here is [Vital](https://vital.audio/), which is an open-source wavetable synthesizer.

# %% [markdown]
# ## Setup Syntheon and test audio files

# %%
# !python -m pip install syntheon
# Out:
# Collecting syntheon
#   Downloading syntheon-0.1.0-py3-none-any.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 85.7 MB/s eta 0:00:00
# Collecting librosa==0.9.1 (from syntheon)
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 25.9 MB/s eta 0:00:00
# Collecting torch==1.12.1 (from syntheon)
#   Downloading torch-1.12.1-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 750.0 kB/s eta 0:00:00
# Collecting torchvision==0.13.1 (from syntheon)
#   Downloading torchvision-0.13.1-cp310-cp310-manylinux1_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 76.5 MB/s eta 0:00:00
# Collecting torchaudio==0.12.1 (from syntheon)
#   Downloading torchaudio-0.12.1-cp310-cp310-manylinux1_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 96.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from syntheon) (6.0.1)
# Collecting mido (from syntheon)
#   Downloading mido-1.3.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 6.6 MB/s eta 0:00:00
# Collecting nnAudio==0.3.1 (from syntheon)
#   Downloading nnAudio-0.3.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from syntheon) (1.23.5)
# Collecting bitstruct (from syntheon)
#   Downloading bitstruct-8.17.0.tar.gz (35 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torchcrepeV2 (from syntheon)
#   Downloading torchcrepeV2-0.2.0-py3-none-any.whl (70.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (3.0.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa==0.9.1->syntheon)
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (0.56.4)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (1.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.1->syntheon) (23.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.12.1->syntheon) (4.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1->syntheon) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.13.1->syntheon) (9.4.0)
# Collecting hmmlearn (from torchcrepeV2->syntheon)
#   Downloading hmmlearn-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 18.2 MB/s eta 0:00:00
# Collecting onnxruntime (from torchcrepeV2->syntheon)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 73.3 MB/s eta 0:00:00
# Collecting onnx (from torchcrepeV2->syntheon)
#   Downloading onnx-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 63.3 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.1->syntheon) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.1->syntheon) (67.7.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.1->syntheon) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1->syntheon) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1->syntheon) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1->syntheon) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.13.1->syntheon) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.1->syntheon) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa==0.9.1->syntheon) (1.15.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx->torchcrepeV2->syntheon) (3.20.3)
# Collecting coloredlogs (from onnxruntime->torchcrepeV2->syntheon)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->torchcrepeV2->syntheon) (23.5.26)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime->torchcrepeV2->syntheon) (1.12)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1->syntheon) (2.21)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->torchcrepeV2->syntheon)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime->torchcrepeV2->syntheon) (1.3.0)
# Building wheels for collected packages: bitstruct
#   Building wheel for bitstruct (setup.py) ... done
#   Created wheel for bitstruct: filename=bitstruct-8.17.0-cp310-cp310-linux_x86_64.whl size=64216 sha256=93c118b7a4ed4368af56b5e1d342e0300632a4f5a5dc17f4f642a0503a8d33e1
#   Stored in directory: /root/.cache/pip/wheels/9e/65/1c/1d738fbe145371947d129a90e926ccd0abeb07e70b9fa5f052
# Successfully built bitstruct
# Installing collected packages: bitstruct, torch, onnx, mido, humanfriendly, torchvision, torchaudio, resampy, nnAudio, coloredlogs, onnxruntime, librosa, hmmlearn, torchcrepeV2, syntheon
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.2+cu118
#     Uninstalling torchaudio-2.0.2+cu118:
#       Successfully uninstalled torchaudio-2.0.2+cu118
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.12.1 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.12.1 which is incompatible.
# Successfully installed bitstruct-8.17.0 coloredlogs-15.0.1 hmmlearn-0.3.0 humanfriendly-10.0 librosa-0.9.1 mido-1.3.0 nnAudio-0.3.1 onnx-1.14.1 onnxruntime-1.15.1 resampy-0.4.2 syntheon-0.1.0 torch-1.12.1 torchaudio-0.12.1 torchcrepeV2-0.2.0 torchvision-0.13.1

# %%
# !git clone https://github.com/gudgud96/syntheon
# Out:
# Cloning into 'syntheon'...
# remote: Enumerating objects: 280, done.
# remote: Counting objects: 100% (280/280), done.
# remote: Compressing objects: 100% (187/187), done.
# remote: Total 280 (delta 119), reused 220 (delta 72), pack-reused 0
# Receiving objects: 100% (280/280), 26.80 MiB | 23.30 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# !mv syntheon/test/test_audio/ .

# %%
import os
from syntheon import infer_params
from google.colab import files

def param_inference(audio_file):
    output_params_file, eval_dict = infer_params(
        audio_file,
        "vital",
        enable_eval=True
    )
    return os.path.join(os.getcwd(), output_params_file), eval_dict
# Out:
# STFT kernels created, time used = 0.1625 seconds
# STFT filter created, time used = 0.0045 seconds
# Mel filter created, time used = 0.0050 seconds
# /usr/local/lib/python3.10/dist-packages/nnAudio/Spectrogram.py:4: Warning: importing Spectrogram subpackage will be deprecated soon. You should import the feature extractor from the feature subpackage. See actual documentation.
#   warnings.warn(

# %% [markdown]
# ## Example 1: Synth Pluck

# %%
#@markdown Synth Pluck example

from IPython.display import Audio
Audio("test_audio/vital_test_pluck_1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Reconstructing with Syntheon...
vital_file, eval_dict = param_inference("test_audio/vital_test_pluck_1.wav")
Audio(eval_dict["output"], rate=16000)
# Out:
# /usr/local/lib/python3.10/dist-packages/syntheon/inferencer/vital/models/preprocessor.py:127: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(f, sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/convert.py:1332: RuntimeWarning: divide by zero encountered in log10
#   + 2 * np.log10(f_sq)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Downloading Vital preset file
files.download(vital_file)

# %% [markdown]
# ## Example 2: Synth Lead

# %%
#@markdown Synth Lead example
from IPython.display import Audio
Audio("test_audio/vital_test_synth_1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Reconstructing with Syntheon...
vital_file, eval_dict = param_inference("test_audio/vital_test_synth_1.wav")
Audio(eval_dict["output"], rate=16000)
# Out:
# /usr/local/lib/python3.10/dist-packages/syntheon/inferencer/vital/models/preprocessor.py:127: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(f, sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/convert.py:1332: RuntimeWarning: divide by zero encountered in log10
#   + 2 * np.log10(f_sq)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Downloading Vital preset file
files.download(vital_file)

# %% [markdown]
# ## Example 3: Wonky Bass

# %%
#@markdown Wonky Bass example

from IPython.display import Audio
Audio("test_audio/vital_test_wonky_bass_1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Reconstructing with Syntheon...

vital_file, eval_dict = param_inference("test_audio/vital_test_wonky_bass_1.wav")
Audio(eval_dict["output"], rate=16000)
# Out:
# /usr/local/lib/python3.10/dist-packages/syntheon/inferencer/vital/models/preprocessor.py:127: FutureWarning: Pass sr=16000 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   x, sr = librosa.load(f, sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/convert.py:1332: RuntimeWarning: divide by zero encountered in log10
#   + 2 * np.log10(f_sq)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Download Vital preset file
files.download(vital_file)
